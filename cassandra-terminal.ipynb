# %%
Last login: Sat Mar 15 13:27:58 on ttys003
(base) fis008@fis008s-MacBook-Air ~ % brew install openjdk@17

zsh: command not found: brew
(base) fis008@fis008s-MacBook-Air ~ % echo 'export PATH="/opt/homebrew/opt/openjdk@17/bin:$PATH"' >> ~/.zshrc
source ~/.zshrc

zsh: permission denied: /Users/fis008/.zshrc
(base) fis008@fis008s-MacBook-Air ~ % brew install cassandra

zsh: command not found: brew
(base) fis008@fis008s-MacBook-Air ~ % /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"

==> Checking for `sudo` access (which may request your password)...
Password:
==> This script will install:
/opt/homebrew/bin/brew
/opt/homebrew/share/doc/homebrew
/opt/homebrew/share/man/man1/brew.1
/opt/homebrew/share/zsh/site-functions/_brew
/opt/homebrew/etc/bash_completion.d/brew
/opt/homebrew

Press RETURN/ENTER to continue or any other key to abort:
==> /usr/bin/sudo /usr/sbin/chown -R fis008:admin /opt/homebrew
==> Downloading and installing Homebrew...
remote: Enumerating objects: 1709, done.
remote: Counting objects: 100% (868/868), done.
remote: Total 1709 (delta 868), reused 868 (delta 868), pack-reused 841 (from 1)
==> Updating Homebrew...
Updated 2 taps (homebrew/core and homebrew/cask).
Warning: /opt/homebrew/bin is not in your PATH.
  Instructions on how to configure your shell for Homebrew
  can be found in the 'Next steps' section below.
==> Installation successful!

==> Homebrew has enabled anonymous aggregate formulae and cask analytics.
Read the analytics documentation (and how to opt-out) here:
  https://docs.brew.sh/Analytics
No analytics data has been sent yet (nor will any be during this install run).

==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
  https://github.com/Homebrew/brew#donations

==> Next steps:
- Run these commands in your terminal to add Homebrew to your PATH:
    echo >> /Users/fis008/.zprofile
    echo 'eval "$(/opt/homebrew/bin/brew shellenv)"' >> /Users/fis008/.zprofile
    eval "$(/opt/homebrew/bin/brew shellenv)"
- Run brew help to get started
- Further documentation:
    https://docs.brew.sh

(base) fis008@fis008s-MacBook-Air ~ % echo 'eval "$(/opt/homebrew/bin/brew shellenv)"' >> ~/.zprofile
eval "$(/opt/homebrew/bin/brew shellenv)"

(base) fis008@fis008s-MacBook-Air ~ % brew --version

Homebrew 4.4.24
(base) fis008@fis008s-MacBook-Air ~ % brew install cassandra

==> Downloading https://ghcr.io/v2/homebrew/core/cassandra/manifests/5.0.3
##################################################################################################################################################################################################### 100.0%
==> Fetching dependencies for cassandra: libev, libpng, freetype, giflib, fontconfig, pcre2, libunistring, gettext, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c@76, harfbuzz, jpeg-turbo, xz, lz4, zstd, libtiff, little-cms2, openjdk@17, mpdecimal, ca-certificates, openssl@3, readline, sqlite and python@3.11
==> Downloading https://ghcr.io/v2/homebrew/core/libev/manifests/4.33
##################################################################################################################################################################################################### 100.0%
==> Fetching libev
==> Downloading https://ghcr.io/v2/homebrew/core/libev/blobs/sha256:67740e5ba01e82c140ceadc512aa26a3990bfadaef0f4b545ba7f9aaf24c50bf
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.47
##################################################################################################################################################################################################### 100.0%
==> Fetching libpng
==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:b4a7f252793b6a2d9d111cecaf5f0c91fd91d9c1c174a8796a487621a05f6f24
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.3
##################################################################################################################################################################################################### 100.0%
==> Fetching freetype
==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:bcd39d3a523690cb0673df46122ff62763c5cd93bfff21bdcab856501d2dfb49
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
##################################################################################################################################################################################################### 100.0%
==> Fetching giflib
==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:bf188a3d3e386e0b100831ca92173118c74645b033b56b4a7c148a91c2cfecb5
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.16.0
##################################################################################################################################################################################################### 100.0%
==> Fetching fontconfig
==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:c3a7405dd151a87f72e7f99c95150da1fc8320ee817c3a17f15a493e1e01057c
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.44
##################################################################################################################################################################################################### 100.0%
==> Fetching pcre2
==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:c3f9e7a70ebc0986af6f0b7c69ac1495fdf4c7420ad831d3daa9c86c448b79c2
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.3
##################################################################################################################################################################################################### 100.0%
==> Fetching libunistring
==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:3cd26bae2d5fcf61294f14c18e5e7ec773a59ed1bf710fb92055e0db0244e909
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.24
##################################################################################################################################################################################################### 100.0%
==> Fetching gettext
==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:be3555b4d0ed00fd50720e3f467cf9ca91fe0645ba29ba206f6bff2763b97e79
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.84.0-1
##################################################################################################################################################################################################### 100.0%
==> Fetching glib
==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:420f2762df64908e59b6052c41580bd03ed980eabbc6b6203c3b4eaa6658ade6
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
##################################################################################################################################################################################################### 100.0%
==> Fetching xorgproto
==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:91066363512e4a3b01644398886815eb370bc8f62611f7ee20c23c7350b4422e
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.12
##################################################################################################################################################################################################### 100.0%
==> Fetching libxau
==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:e8a5fedbd9e5c49f10006171decc5b1e56c48fbd4267e7668f813e47c0da984f
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
##################################################################################################################################################################################################### 100.0%
==> Fetching libxdmcp
==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:b09a915dae5b45371a86f20a4ccce13c16c7a8eadc843b665e91bc5b2d2143ce
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0-1
##################################################################################################################################################################################################### 100.0%
==> Fetching libxcb
==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:cce8d9e12c3f0b2fdbffbb3f7ba02f7e25cf3fa495b3e759d34a6264599543b3
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.12
##################################################################################################################################################################################################### 100.0%
==> Fetching libx11
==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:57ccd55767fd6ffc7d32940d1c59d59b42c82abff4abf795b4ca0df489da42f1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
##################################################################################################################################################################################################### 100.0%
==> Fetching libxext
==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:a0434e871b6dfa64f18757e5d6df179308bcf1b53e5fa233c7d54222be8d513b
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.12
##################################################################################################################################################################################################### 100.0%
==> Fetching libxrender
==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:edcb8884f9d33219d276051be3b5ad64f390cdf3abe9794d9a0050c02895c3a7
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
##################################################################################################################################################################################################### 100.0%
==> Fetching lzo
==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:6bb0401c41a18fd37071ec9591fe053a808f07552ff7ea22542faa470eb8e589
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.44.2
##################################################################################################################################################################################################### 100.0%
==> Fetching pixman
==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:8ec43a3f69d7c97d8ce1d07611638040c8ebec305e7dd76cb02dc3609982fa9f
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.4
##################################################################################################################################################################################################### 100.0%
==> Fetching cairo
==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:6b2d148a34a670430a459c374376ebed890b61eb7573e8aa952a4b909f443cee
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
##################################################################################################################################################################################################### 100.0%
==> Fetching graphite2
==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:150b286ab4cfc8696fcd3fa4e7fa24c9825f024ef991899850b850e6f334100f
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/manifests/76.1_1
##################################################################################################################################################################################################### 100.0%
==> Fetching icu4c@76
==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/blobs/sha256:66a2995c046a7d78b727cac1b90f52a2fd3bcf07488ae41c711109bbd1fca8e1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/10.4.0
##################################################################################################################################################################################################### 100.0%
==> Fetching harfbuzz
==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:3f8f12c182943f1c4215b3bae44d0d729fd478620a89b9f4e04ad79b8eb740a0
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.1.0
##################################################################################################################################################################################################### 100.0%
==> Fetching jpeg-turbo
==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:c43b108ab9895d7aa1f649d9d3b10da482657eb1216d060577142b805cfe490c
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.6.4
##################################################################################################################################################################################################### 100.0%
==> Fetching xz
==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:b49f3559f9425b0a8c8de8806b2162d757196c06d4043e65c6654e88cdac15e0
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.10.0-1
##################################################################################################################################################################################################### 100.0%
==> Fetching lz4
==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:5bd143b7b784989e549637ea4e484af85ba481e640dde69bc35f3843ae25abc6
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.7
##################################################################################################################################################################################################### 100.0%
==> Fetching zstd
==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:b039c851ef22617804576274872c33727ebb3a0b5e0db2ab62e0d8a97ec9605a
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.7.0-1
##################################################################################################################################################################################################### 100.0%
==> Fetching libtiff
==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:5f771cedcb37119c3927c32d72589a66701db16fe3ef86b2daf9b87c3142b309
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.17
##################################################################################################################################################################################################### 100.0%
==> Fetching little-cms2
==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:3827b5a8583f0e92987bd0e7c721bda834157ad366d2cb66596559dd8654c9ac
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/openjdk/17/manifests/17.0.14-1
##################################################################################################################################################################################################### 100.0%
==> Fetching openjdk@17
==> Downloading https://ghcr.io/v2/homebrew/core/openjdk/17/blobs/sha256:ad49acafe0bbbd4e5459f386239fb2dc44171965d69a5071e4d403f14ea61a2f
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/mpdecimal/manifests/4.0.0-1
##################################################################################################################################################################################################### 100.0%
==> Fetching mpdecimal
==> Downloading https://ghcr.io/v2/homebrew/core/mpdecimal/blobs/sha256:0f5f269bed0e6be2de3edfc4b52867e656f993e5bcff40717f26ee94dd0d2211
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2025-02-25
##################################################################################################################################################################################################### 100.0%
==> Fetching ca-certificates
==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:8f46fb05f753f80f2bc398c0a24b10d680bd77d496e2b931de0b61998e37aebc
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.4.1
##################################################################################################################################################################################################### 100.0%
==> Fetching openssl@3
==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:b20c7d9b63e7b320cba173c11710dee9888c77175a841031d7a245bb37355b98
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.2.13
##################################################################################################################################################################################################### 100.0%
==> Fetching readline
==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:738c27ceee9a8b198f98438477ef7a513a96a965e3a434ac3aa8fb4ed76494b1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.49.1
##################################################################################################################################################################################################### 100.0%
==> Fetching sqlite
==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:757c3d60f4d35fe1c3336207d63992fc804fa6ddd2c40ebb84eb7bfa07bc69e1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/manifests/3.11.11
##################################################################################################################################################################################################### 100.0%
==> Fetching python@3.11
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/blobs/sha256:df6d9256d4f66b3b119d91471d693bcde4f7d02b49121b8ae5605d8c9c5b7552
##################################################################################################################################################################################################### 100.0%
==> Fetching cassandra
==> Downloading https://ghcr.io/v2/homebrew/core/cassandra/blobs/sha256:e3966d3906adbb114e9b0a5967c9299079944904fcea9ad1518f84ee923904db
##################################################################################################################################################################################################### 100.0%
==> Installing dependencies for cassandra: libev, libpng, freetype, giflib, fontconfig, pcre2, libunistring, gettext, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c@76, harfbuzz, jpeg-turbo, xz, lz4, zstd, libtiff, little-cms2, openjdk@17, mpdecimal, ca-certificates, openssl@3, readline, sqlite and python@3.11
==> Installing cassandra dependency: libev
==> Downloading https://ghcr.io/v2/homebrew/core/libev/manifests/4.33
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/dcc77a4ef78cc646caf5e0675f4121c18ac6fbbb84ddb181eaab408546c41b66--libev-4.33.bottle_manifest.json
==> Pouring libev--4.33.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libev/4.33: 13 files, 503.5KB
==> Installing cassandra dependency: libpng
==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.47
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/072d8f136f69cf75140ffb8a832f60b362a14dba897d78ed7fc83e3ca30b2ede--libpng-1.6.47.bottle_manifest.json
==> Pouring libpng--1.6.47.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libpng/1.6.47: 28 files, 1.3MB
==> Installing cassandra dependency: freetype
==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.3
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/4c4d14d574a7af9a5a0220cd5012c698bd87b75a3d5e39a6a6c34b4c411aab52--freetype-2.13.3.bottle_manifest.json
==> Pouring freetype--2.13.3.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/freetype/2.13.3: 68 files, 2.5MB
==> Installing cassandra dependency: giflib
==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/283773c4d2db4fe867419d7eea6811a6417889d78fad8871041c07f49b22d2a1--giflib-5.2.2.bottle_manifest.json
==> Pouring giflib--5.2.2.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/giflib/5.2.2: 20 files, 546.9KB
==> Installing cassandra dependency: fontconfig
==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.16.0
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/6897fed6b85e0f537cb8774ec21346308111caaf26c136f33fdc95302d361fe7--fontconfig-2.16.0.bottle_manifest.json
==> Pouring fontconfig--2.16.0.arm64_sequoia.bottle.tar.gz
==> Regenerating font cache, this may take a while
==> /opt/homebrew/Cellar/fontconfig/2.16.0/bin/fc-cache -frv
🍺  /opt/homebrew/Cellar/fontconfig/2.16.0: 92 files, 1.5MB
==> Installing cassandra dependency: pcre2
==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.44
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/22ed791461c5bf400adde8c3b432c1230866aa1db3c5cb81e06a6ff21cac96ee--pcre2-10.44.bottle_manifest.json
==> Pouring pcre2--10.44.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/pcre2/10.44: 237 files, 6.3MB
==> Installing cassandra dependency: libunistring
==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.3
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/a570da63bc1839c7e217f203abd54d4d873ebd6b99f6e88994d0e79e2ebe987c--libunistring-1.3.bottle_manifest.json
==> Pouring libunistring--1.3.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libunistring/1.3: 59 files, 5.4MB
==> Installing cassandra dependency: gettext
==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.24
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/8abb4a73a097ce307663b52d2da2d1d9b10df035244eb566425042eee157d0b3--gettext-0.24.bottle_manifest.json
==> Pouring gettext--0.24.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/gettext/0.24: 2,189 files, 19.9MB
==> Installing cassandra dependency: glib
==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.84.0-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/42c577126c289c98bbbbac138449b36e56a9949d957d89814d047506e46663af--glib-2.84.0-1.bottle_manifest.json
==> Pouring glib--2.84.0.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/glib/2.84.0: 504 files, 36.6MB
==> Installing cassandra dependency: xorgproto
==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/d89d69340366d1d015e7214520f64081e2d82d7955fb28c6ea5f6539dcb610b2--xorgproto-2024.1.bottle_manifest.json
==> Pouring xorgproto--2024.1.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/xorgproto/2024.1: 268 files, 3.9MB
==> Installing cassandra dependency: libxau
==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.12
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/6335be202d59f96fdee2e4a02f93d8ee87dfcfdbaa4ed132b8fe8c3e3651e27c--libxau-1.0.12.bottle_manifest.json
==> Pouring libxau--1.0.12.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libxau/1.0.12: 21 files, 134.3KB
==> Installing cassandra dependency: libxdmcp
==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/8713e53f73d0be64780dbea522b0ee07027e6cc7828ff1a4fa0a6596f14cfe25--libxdmcp-1.1.5.bottle_manifest.json
==> Pouring libxdmcp--1.1.5.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libxdmcp/1.1.5: 12 files, 140.0KB
==> Installing cassandra dependency: libxcb
==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/a17e9d0e04a0013a5be592875b012c409023664b3df084b8051766331d213ff5--libxcb-1.17.0-1.bottle_manifest.json
==> Pouring libxcb--1.17.0.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/libxcb/1.17.0: 2,498 files, 7.5MB
==> Installing cassandra dependency: libx11
==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.12
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/8510ddcf75e7c4313fe4f8b0999d667b22f2ae0b850bc80ba53becb609335934--libx11-1.8.12.bottle_manifest.json
==> Pouring libx11--1.8.12.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libx11/1.8.12: 1,043 files, 7MB
==> Installing cassandra dependency: libxext
==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/fedb843acbfcf682fb451396914bfc096f9ea2748376d4c43ce2af7ce1b766b7--libxext-1.3.6.bottle_manifest.json
==> Pouring libxext--1.3.6.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libxext/1.3.6: 88 files, 458.4KB
==> Installing cassandra dependency: libxrender
==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.12
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/152fb22ff88a23b62841dcfa14aac21018e1d736c072d732185f6139ef922e1c--libxrender-0.9.12.bottle_manifest.json
==> Pouring libxrender--0.9.12.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/libxrender/0.9.12: 13 files, 225.3KB
==> Installing cassandra dependency: lzo
==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/d4aa5b0c239912c53bc857d1012c6b7feb4acb509618f5e100f95bf8521f08e7--lzo-2.10.bottle_manifest.json
==> Pouring lzo--2.10.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/lzo/2.10: 32 files, 567.9KB
==> Installing cassandra dependency: pixman
==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.44.2
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/710d020ae0348db5aff5d6dbdfd222dca000e630d64e8dcd5f8a8499e8131681--pixman-0.44.2.bottle_manifest.json
==> Pouring pixman--0.44.2.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/pixman/0.44.2: 10 files, 655.6KB
==> Installing cassandra dependency: cairo
==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.4
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/795ef2e2e2a57e6baba0fc9ceedb58980e8ec718aba0170b9441a0b25442cfbf--cairo-1.18.4.bottle_manifest.json
==> Pouring cairo--1.18.4.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/cairo/1.18.4: 53 files, 2.2MB
==> Installing cassandra dependency: graphite2
==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/bbb4dd2ef1846301d1eb08053e19e11ca9c780f93f4d3b2d638fd94a9bf54a0c--graphite2-1.3.14.bottle_manifest.json
==> Pouring graphite2--1.3.14.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/graphite2/1.3.14: 19 files, 284.8KB
==> Installing cassandra dependency: icu4c@76
==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/manifests/76.1_1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/c105f8980d3a6b0ff0253b47492e886520580406ee75fa52509cf5b251b4d633--icu4c@76-76.1_1.bottle_manifest.json
==> Pouring icu4c@76--76.1_1.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/icu4c@76/76.1_1: 277 files, 81MB
==> Installing cassandra dependency: harfbuzz
==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/10.4.0
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/b7209e28b6339dd7642dda11883c4a5c99facd09fba5dd584fe5517b74ae9d6e--harfbuzz-10.4.0.bottle_manifest.json
==> Pouring harfbuzz--10.4.0.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/harfbuzz/10.4.0: 77 files, 9.9MB
==> Installing cassandra dependency: jpeg-turbo
==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.1.0
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/6a56a664f24b0435ac129cb33185ae84d884e0f2357ac6fd37727dad9ac5c7d7--jpeg-turbo-3.1.0.bottle_manifest.json
==> Pouring jpeg-turbo--3.1.0.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/jpeg-turbo/3.1.0: 47 files, 3.5MB
==> Installing cassandra dependency: xz
==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.6.4
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/d14e84095418591f4112922f1a834dbac6c7e4fdc334eae0aaff35e2b860cc5b--xz-5.6.4.bottle_manifest.json
==> Pouring xz--5.6.4.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/xz/5.6.4: 96 files, 2.0MB
==> Installing cassandra dependency: lz4
==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.10.0-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/8e11e90eb21a06e0f199af9d80e011e3693c77dd353b2477579d95c8471a5802--lz4-1.10.0-1.bottle_manifest.json
==> Pouring lz4--1.10.0.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/lz4/1.10.0: 24 files, 713.6KB
==> Installing cassandra dependency: zstd
==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.7
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/596a67b1677f62a8e24e6fdfa7c879891221cb8261242f4355fb4deff1a2ec39--zstd-1.5.7.bottle_manifest.json
==> Pouring zstd--1.5.7.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/zstd/1.5.7: 32 files, 2.2MB
==> Installing cassandra dependency: libtiff
==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.7.0-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/cc8add3c5369d6c22906554ebc395ebe89f1ac410112bd65bc6d286d4e02f210--libtiff-4.7.0-1.bottle_manifest.json
==> Pouring libtiff--4.7.0.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/libtiff/4.7.0: 486 files, 8.4MB
==> Installing cassandra dependency: little-cms2
==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.17
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/0e5e5ac9e1df07ae001662a85a70b344b31345897c284172f14874c9d329cb85--little-cms2-2.17.bottle_manifest.json
==> Pouring little-cms2--2.17.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/little-cms2/2.17: 23 files, 1.4MB
==> Installing cassandra dependency: openjdk@17
==> Downloading https://ghcr.io/v2/homebrew/core/openjdk/17/manifests/17.0.14-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/bb1f4418cd7cb469ab902ea185d33a07f6a837f58930b575bb669712613e0623--openjdk@17-17.0.14-1.bottle_manifest.json
==> Pouring openjdk@17--17.0.14.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/openjdk@17/17.0.14: 636 files, 304.2MB
==> Installing cassandra dependency: mpdecimal
==> Downloading https://ghcr.io/v2/homebrew/core/mpdecimal/manifests/4.0.0-1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/7b63c3b34bee402290af49fac829a6682ab45ea5c9258b6fe03b590a03a4c4a9--mpdecimal-4.0.0-1.bottle_manifest.json
==> Pouring mpdecimal--4.0.0.arm64_sequoia.bottle.1.tar.gz
🍺  /opt/homebrew/Cellar/mpdecimal/4.0.0: 22 files, 641.3KB
==> Installing cassandra dependency: ca-certificates
==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2025-02-25
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/6c1debb525d4dc6007afae4cd2b772105111632b22fc28506550f6dfe27c6d52--ca-certificates-2025-02-25.bottle_manifest.json
==> Pouring ca-certificates--2025-02-25.all.bottle.tar.gz
==> Regenerating CA certificate bundle from keychain, this may take a while...
🍺  /opt/homebrew/Cellar/ca-certificates/2025-02-25: 4 files, 235.9KB
==> Installing cassandra dependency: openssl@3
==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.4.1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/a2bb8b71ebddb1fe8553581fcbc1ffc4ab36795c68b3cd47977cf83f1673a5b1--openssl@3-3.4.1.bottle_manifest.json
==> Pouring openssl@3--3.4.1.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/openssl@3/3.4.1: 7,236 files, 33.4MB
==> Installing cassandra dependency: readline
==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.2.13
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/aa1afa38997a2866d91c81fdda8b36d436cd4ea7a82aed07d13c83c56eb3460e--readline-8.2.13.bottle_manifest.json
==> Pouring readline--8.2.13.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/readline/8.2.13: 51 files, 1.7MB
==> Installing cassandra dependency: sqlite
==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.49.1
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/ce3cf24bf33f0eff2d169e046ba5da3ec75ab9fe0439e7b7face44f42e033fcb--sqlite-3.49.1.bottle_manifest.json
==> Pouring sqlite--3.49.1.arm64_sequoia.bottle.tar.gz
🍺  /opt/homebrew/Cellar/sqlite/3.49.1: 13 files, 4.7MB
==> Installing cassandra dependency: python@3.11
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/manifests/3.11.11
Already downloaded: /Users/fis008/Library/Caches/Homebrew/downloads/8a8898a42ed57965cbfcfbbb6071d245678db8887c6a6eea89e241eed49e08cf--python@3.11-3.11.11.bottle_manifest.json
==> Pouring python@3.11--3.11.11.arm64_sequoia.bottle.tar.gz
==> /opt/homebrew/Cellar/python@3.11/3.11.11/bin/python3.11 -Im ensurepip
==> /opt/homebrew/Cellar/python@3.11/3.11.11/bin/python3.11 -Im pip install -v --no-index --upgrade --isolated --target=/opt/homebrew/lib/python3.11/site-packages /opt/homebrew/Cellar/python@3.11/3.11.11/
🍺  /opt/homebrew/Cellar/python@3.11/3.11.11: 3,306 files, 62MB
==> Installing cassandra
==> Pouring cassandra--5.0.3.arm64_sequoia.bottle.tar.gz
==> Caveats
To start cassandra now and restart at login:
  brew services start cassandra
Or, if you don't want/need a background service you can just run:
  /opt/homebrew/opt/cassandra/bin/cassandra -f
==> Summary
🍺  /opt/homebrew/Cellar/cassandra/5.0.3: 379 files, 74.7MB
==> Running `brew cleanup cassandra`...
Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
==> Caveats
==> cassandra
To start cassandra now and restart at login:
  brew services start cassandra
Or, if you don't want/need a background service you can just run:
  /opt/homebrew/opt/cassandra/bin/cassandra -f
(base) fis008@fis008s-MacBook-Air ~ % brew services start cassandra

==> Tapping homebrew/services
Cloning into '/opt/homebrew/Library/Taps/homebrew/homebrew-services'...
remote: Enumerating objects: 4191, done.
remote: Counting objects: 100% (468/468), done.
remote: Compressing objects: 100% (139/139), done.
remote: Total 4191 (delta 386), reused 329 (delta 329), pack-reused 3723 (from 4)
Receiving objects: 100% (4191/4191), 1.28 MiB | 3.93 MiB/s, done.
Resolving deltas: 100% (2030/2030), done.
Tapped 2 commands (53 files, 1.5MB).
==> Successfully started `cassandra` (label: homebrew.mxcl.cassandra)
(base) fis008@fis008s-MacBook-Air ~ % nodetool status

Exception in thread "main" java.lang.IllegalArgumentException: Server is not initialized yet, cannot run nodetool.
	at org.apache.cassandra.tools.NodeTool.err(NodeTool.java:320)
	at org.apache.cassandra.tools.NodeTool.execute(NodeTool.java:283)
	at org.apache.cassandra.tools.NodeTool.main(NodeTool.java:85)
(base) fis008@fis008s-MacBook-Air ~ % brew services restart cassandra

Stopping `cassandra`... (might take a while)
==> Successfully stopped `cassandra` (label: homebrew.mxcl.cassandra)
==> Successfully started `cassandra` (label: homebrew.mxcl.cassandra)
(base) fis008@fis008s-MacBook-Air ~ % nodetool status

Datacenter: datacenter1
=======================
Status=Up/Down
|/ State=Normal/Leaving/Joining/Moving
--  Address    Load        Tokens  Owns (effective)  Host ID                               Rack 
UN  127.0.0.1  136.29 KiB  16      100.0%            d2af6b1b-799d-4664-895e-aeef96d0e882  rack1

(base) fis008@fis008s-MacBook-Air ~ % cqlsh

Connected to Test Cluster at 127.0.0.1:9042
[cqlsh 6.2.0 | Cassandra 5.0.3 | CQL spec 3.4.7 | Native protocol v5]
Use HELP for help.
cqlsh> CREATE KEYSPACE my_keyspace WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 3};

Warnings :
Your replication factor 3 for keyspace my_keyspace is higher than the number of nodes 1

cqlsh> 
cqlsh> CREATE TABLE my_keyspace.my_table (
   ...     id UUID PRIMARY KEY,
   ...     name text,
   ...     age int
   ... );
cqlsh> 
cqlsh> CREATE KEYSPACE my_keyspace WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};
AlreadyExists: Keyspace 'my_keyspace' already exists
cqlsh> 
cqlsh> CREATE TABLE my_keyspace.my_table (
   ...     id UUID PRIMARY KEY,
   ...     name text,
   ...     age int
   ... );
AlreadyExists: Table 'my_keyspace.my_table' already exists
cqlsh> 
cqlsh> help

Documented shell commands:
===========================
CAPTURE  CLS          COPY  DESCRIBE  EXPAND  HISTORY  PAGING  SHOW    TRACING
CLEAR    CONSISTENCY  DESC  EXIT      HELP    LOGIN    SERIAL  SOURCE  UNICODE

CQL help topics:
================
AGGREGATES               CREATE_KEYSPACE           DROP_TRIGGER      TEXT     
ALTER_KEYSPACE           CREATE_MATERIALIZED_VIEW  DROP_TYPE         TIME     
ALTER_MATERIALIZED_VIEW  CREATE_ROLE               DROP_USER         TIMESTAMP
ALTER_TABLE              CREATE_TABLE              FUNCTIONS         TRUNCATE 
ALTER_TYPE               CREATE_TRIGGER            GRANT             TYPES    
ALTER_USER               CREATE_TYPE               INSERT            UPDATE   
APPLY                    CREATE_USER               INSERT_JSON       USE      
ASCII                    DATE                      INT               UUID     
BATCH                    DELETE                    JSON            
BEGIN                    DROP_AGGREGATE            KEYWORDS        
BLOB                     DROP_COLUMNFAMILY         LIST_PERMISSIONS
BOOLEAN                  DROP_FUNCTION             LIST_ROLES      
COUNTER                  DROP_INDEX                LIST_USERS      
CREATE_AGGREGATE         DROP_KEYSPACE             PERMISSIONS     
CREATE_COLUMNFAMILY      DROP_MATERIALIZED_VIEW    REVOKE          
CREATE_FUNCTION          DROP_ROLE                 SELECT          
CREATE_INDEX             DROP_TABLE                SELECT_JSON     

cqlsh> DESCRIBE KEYSPACES;

data_quran   system_auth         system_traces        
my_keyspace  system_distributed  system_views         
system       system_schema       system_virtual_schema

cqlsh> DESCRIBE KEYSPACES;

data_quran    system              system_schema  system_virtual_schema
my_keyspace   system_auth         system_traces
settrade_api  system_distributed  system_views 

cqlsh> DESCRIBE KEYSPACES;

data_quran    system              system_schema  system_virtual_schema
my_keyspace   system_auth         system_traces
settrade_api  system_distributed  system_views 

cqlsh> DESCRIBE KEYSPACES;

data_quran    system              system_schema  system_virtual_schema
my_keyspace   system_auth         system_traces
settrade_api  system_distributed  system_views 

cqlsh> DESCRIBE KEYSPACES;

data_quran    system              system_schema  system_virtual_schema
my_keyspace   system_auth         system_traces
settrade_api  system_distributed  system_views 

cqlsh> DESCRIBE KEYSPACES;

data_quran    system              system_schema  system_virtual_schema
my_keyspace   system_auth         system_traces
settrade_api  system_distributed  system_views 

cqlsh> CREATE KEYSPACE stock_data WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};
cqlsh> DESCRIBE KEYSPACES;

data_quran    stock_data   system_distributed  system_views         
my_keyspace   system       system_schema       system_virtual_schema
settrade_api  system_auth  system_traces     

cqlsh> USE stock_data;
cqlsh:stock_data> DESCRIBE TABLES;
cqlsh:stock_data> CREATE TABLE candlestick_data (
              ...     symbol TEXT,
              ...     time TIMESTAMP PRIMARY KEY,
              ...     open_price FLOAT,
              ...     high_price FLOAT,
              ...     low_price FLOAT,
              ...     close_price FLOAT,
              ...     volume INT,
              ...     value FLOAT
              ... );
cqlsh:stock_data> 
cqlsh:stock_data> DESCRIBE TABLE candlestick_data;

CREATE TABLE stock_data.candlestick_data (
    time timestamp PRIMARY KEY,
    close_price float,
    high_price float,
    low_price float,
    open_price float,
    symbol text,
    value float,
    volume int
) WITH additional_write_policy = '99p'
    AND allow_auto_snapshot = true
    AND bloom_filter_fp_chance = 0.01
    AND caching = {'keys': 'ALL', 'rows_per_partition': 'NONE'}
    AND cdc = false
    AND comment = ''
    AND compaction = {'class': 'org.apache.cassandra.db.compaction.SizeTieredCompactionStrategy', 'max_threshold': '32', 'min_threshold': '4'}
    AND compression = {'chunk_length_in_kb': '16', 'class': 'org.apache.cassandra.io.compress.LZ4Compressor'}
    AND memtable = 'default'
    AND crc_check_chance = 1.0
    AND default_time_to_live = 0
    AND extensions = {}
    AND gc_grace_seconds = 864000
    AND incremental_backups = true
    AND max_index_interval = 2048
    AND memtable_flush_period_in_ms = 0
    AND min_index_interval = 128
    AND read_repair = 'BLOCKING'
    AND speculative_retry = '99p';
cqlsh:stock_data> SELECT * FROM candlestick_data;

 time                            | close_price | high_price | low_price | open_price | symbol |
 2025-02-07 00:00:00.000000+0000 |         118 |        119 |       118 |        119 |    NEW |       23700 |      200
 2023-05-09 00:00:00.000000+0000 |        0.48 |       0.48 |      0.46 |       0.47 |   ACAP |  6.4708e+05 |  1356000
 2025-02-04 00:00:00.000000+0000 |        1.35 |       1.35 |       1.1 |        1.1 |    MUD |  26212.2207 |    22201
 2025-02-05 00:00:00.000000+0000 |        7.35 |       7.35 |       7.2 |        7.2 | M-STOR |       15135 |     2100
 2025-01-29 00:00:00.000000+0000 |         9.1 |        9.9 |       9.1 |        9.9 |   MIPF |        4785 |      500
 2025-03-17 00:00:00.000000+0000 |         190 |        190 |       190 |        190 |   SCCC |       19000 |      100
 2024-09-13 00:00:00.000000+0000 |        0.27 |       0.29 |      0.27 |       0.28 |    JKN |  4.5984e+06 | 16862624
 2025-02-11 00:00:00.000000+0000 |         120 |        125 |       119 |        119 |    NEW |     73530.5 |      601
 2024-07-24 00:00:00.000000+0000 |        0.03 |       0.04 |      0.03 |       0.03 |    KKC | 52314.51953 |  1741751
 2024-09-03 00:00:00.000000+0000 |        0.39 |       0.44 |      0.37 |       0.38 |    JKN |  2.4324e+07 | 60150728
 2023-05-03 00:00:00.000000+0000 |        0.44 |       0.44 |      0.39 |       0.39 |   ACAP |  4.4027e+05 |  1032611
 2023-05-12 00:00:00.000000+0000 |        0.48 |        0.5 |      0.46 |        0.5 |   ACAP |  5.4745e+05 |  1145622
 2023-05-16 00:00:00.000000+0000 |        0.29 |       0.38 |      0.29 |       0.35 |   ACAP |  3.9581e+06 | 12805628
 2025-03-04 00:00:00.000000+0000 |         6.3 |       6.55 |       5.6 |       5.65 | SINGER |  9.7123e+07 | 15615793
 2024-07-23 00:00:00.000000+0000 |        0.04 |       0.04 |      0.02 |       0.02 |    KKC |       46874 |  1575200
 2025-02-19 00:00:00.000000+0000 |        0.17 |       0.18 |      0.16 |       0.16 |    SAM |       32901 |   192300
 2023-05-11 00:00:00.000000+0000 |        0.49 |       0.49 |      0.46 |       0.47 |   ACAP |  5.2224e+05 |  1092304
 2024-07-16 00:00:00.000000+0000 |        0.04 |       0.04 |      0.03 |       0.03 |    KKC | 18895.73047 |   532791
 2024-07-17 00:00:00.000000+0000 |        0.03 |       0.04 |      0.03 |       0.03 |    KKC |  1.2124e+05 |  4030320
 2025-03-11 00:00:00.000000+0000 |        6.75 |        6.9 |       6.4 |       6.45 | SINGER |  4.5715e+07 |  6867073
 2025-03-06 00:00:00.000000+0000 |        6.45 |        6.7 |       6.3 |        6.5 | SINGER |  6.6791e+07 | 10239128
 2024-09-09 00:00:00.000000+0000 |        0.34 |       0.35 |      0.33 |       0.33 |    JKN |  4.8911e+06 | 14433586
 2025-01-28 00:00:00.000000+0000 |         9.9 |        9.9 |       9.9 |        9.9 |   MIPF |        4950 |      500
 2024-09-16 00:00:00.000000+0000 |        0.31 |       0.32 |      0.25 |       0.26 |    JKN |  1.2123e+07 | 43155573
 2025-02-17 00:00:00.000000+0000 |        0.16 |       0.16 |      0.15 |       0.15 |    SAM | 24381.58008 |   159004
 2024-09-10 00:00:00.000000+0000 |        0.34 |       0.35 |      0.33 |       0.34 |    JKN |  2.1575e+06 |  6396411
 2025-02-03 00:00:00.000000+0000 |        7.35 |       7.35 |       7.1 |        7.1 | M-STOR |       10675 |     1500
 2024-09-04 00:00:00.000000+0000 |        0.37 |        0.4 |      0.36 |       0.39 |    JKN |  6.9851e+06 | 18504030
 2025-01-27 00:00:00.000000+0000 |        10.1 |       10.1 |       9.9 |        9.9 |   MIPF |       15980 |     1600
 2024-07-19 00:00:00.000000+0000 |        0.03 |       0.03 |      0.02 |       0.03 |    KKC | 37278.16016 |  1246972
 2025-02-27 00:00:00.000000+0000 |       42.25 |       42.5 |     42.25 |       42.5 |  SHANG |       10478 |      250
 2023-05-02 00:00:00.000000+0000 |        0.41 |       0.43 |      0.39 |        0.4 |   ACAP |  2.5591e+05 |   622148
 2025-03-14 00:00:00.000000+0000 |         6.6 |       6.75 |       6.4 |       6.45 | SINGER |  4.3938e+07 |  6703829
 2025-02-21 00:00:00.000000+0000 |           2 |          2 |         2 |          2 |  SE-ED |         800 |      400
 2025-03-12 00:00:00.000000+0000 |         6.6 |        6.8 |      6.45 |        6.7 | SINGER |  3.2396e+07 |  4913785
 2025-01-31 00:00:00.000000+0000 |          29 |      29.75 |        29 |      29.75 | MANRIN |  2.0402e+05 |     6959
 2023-05-08 00:00:00.000000+0000 |        0.48 |        0.5 |      0.41 |       0.41 |   ACAP |  8.0901e+05 |  1699500
 2024-09-11 00:00:00.000000+0000 |         0.3 |       0.34 |       0.3 |       0.33 |    JKN |   3.748e+06 | 11995669
 2025-02-18 00:00:00.000000+0000 |        0.16 |       0.17 |      0.15 |       0.15 |    SAM |  1.8756e+05 |  1151105

(69 rows)
cqlsh:stock_data> SELECT * FROM candlestick_data WHERE symbol = 'BBL' LIMIT 10;
InvalidRequest: Error from server: code=2200 [Invalid query] message="Cannot execute this query as it might involve data filtering and thus may have unpredictable performance. If you want to execute this query despite the performance unpredictability, use ALLOW FILTERING"
cqlsh:stock_data> SELECT * FROM candlestick_data WHERE symbol = 'BBL' LIMIT 10;
InvalidRequest: Error from server: code=2200 [Invalid query] message="Cannot execute this query as it might involve data filtering and thus may have unpredictable performance. If you want to execute this query despite the performance unpredictability, use ALLOW FILTERING"
cqlsh:stock_data> SELECT * FROM candlestick_data WHERE symbol = 'SAM' LIMIT 10;
InvalidRequest: Error from server: code=2200 [Invalid query] message="Cannot execute this query as it might involve data filtering and thus may have unpredictable performance. If you want to execute this query despite the performance unpredictability, use ALLOW FILTERING"
cqlsh:stock_data> SELECT * FROM candlestick_data WHERE symbol = 'SAM' LIMIT 10 ALLOW FILTERING;

 time                            | close_price | high_price | low_price | open_price | symbol | value       | volume
---------------------------------+-------------+------------+-----------+------------+--------+-------------+---------
 2025-02-20 00:00:00.000000+0000 |        0.18 |       0.18 |      0.16 |       0.17 |    SAM |  3.5316e+05 | 2032101
 2025-02-14 00:00:00.000000+0000 |        0.16 |       0.16 |      0.15 |       0.16 |    SAM |       28631 |  179200
 2025-02-19 00:00:00.000000+0000 |        0.17 |       0.18 |      0.16 |       0.16 |    SAM |       32901 |  192300
 2025-02-17 00:00:00.000000+0000 |        0.16 |       0.16 |      0.15 |       0.15 |    SAM | 24381.58008 |  159004
 2025-02-18 00:00:00.000000+0000 |        0.16 |       0.17 |      0.15 |       0.15 |    SAM |  1.8756e+05 | 1151105

(5 rows)
cqlsh:stock_data> SELECT * FROM candlestick_data WHERE symbol = 'SAM' LIMIT 10 ALLOW FILTERING;

 time                            | close_price | high_price | low_price | open_price | symbol | value       | volume
---------------------------------+-------------+------------+-----------+------------+--------+-------------+---------
 2025-02-20 00:00:00.000000+0000 |        0.18 |       0.18 |      0.16 |       0.17 |    SAM |  3.5316e+05 | 2032101
 2025-02-14 00:00:00.000000+0000 |        0.16 |       0.16 |      0.15 |       0.16 |    SAM |       28631 |  179200
 2025-02-19 00:00:00.000000+0000 |        0.17 |       0.18 |      0.16 |       0.16 |    SAM |       32901 |  192300
 2025-02-17 00:00:00.000000+0000 |        0.16 |       0.16 |      0.15 |       0.15 |    SAM | 24381.58008 |  159004
 2025-02-18 00:00:00.000000+0000 |        0.16 |       0.17 |      0.15 |       0.15 |    SAM |  1.8756e+05 | 1151105

(5 rows)
cqlsh:stock_data>
