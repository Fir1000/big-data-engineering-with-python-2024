# %%
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv
import matplotlib.pyplot as plt
from cassandra.cluster import Cluster
import requests
from fuzzywuzzy import fuzz
from collections import defaultdict
from fuzzywuzzy import process
from nltk.tokenize import word_tokenize
from settrade_v2 import Investor
from pprint import pprint
from settrade_v2 import Investor
from datetime import datetime

# %%
cluster = Cluster(['127.0.0.1']) 
session = cluster.connect()

# %%
# สร้าง Keyspace หากยังไม่มี
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS settrade_api 
    WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1}
""")

# ใช้ Keyspace ที่สร้างขึ้น
session.set_keyspace('settrade_api')

print("Keyspace 'settrade_api ' ถูกสร้างและใช้งานเรียบร้อย!")
# Out:
# Keyspace 'settrade_api ' ถูกสร้างและใช้งานเรียบร้อย!

# %%
investor = Investor(
                    app_id="Fbje7lpwr6o7YR3R",
                    app_secret="AOSgCl7HCoygpILitghGHH74TodilCz13a+LHNgg9DSS",
                    broker_id="SANDBOX",
                    app_code="SANDBOX",
                    is_auto_queue = False)

# %%
# กรณี Investor
market = investor.MarketData()


res = market.get_candlestick(
    symbol="BBL",
    interval="1d",
    limit=1,
    normalized=True,
)

print(res)
# Out:
# {'lastSequence': 112372, 'time': [1742144400], 'open': [146.5], 'high': [150.0], 'low': [146.0], 'close': [146.5], 'volume': [2600], 'value': [383950.0]}

# %%
print(res)
print(type(res))
# Out:
# {'lastSequence': 112372, 'time': [1742144400], 'open': [146.5], 'high': [150.0], 'low': [146.0], 'close': [146.5], 'volume': [2600], 'value': [383950.0]}
# <class 'dict'>

# %%
# 👉 เชื่อมต่อ Cassandra
cluster = Cluster(['127.0.0.1'])  # Localhost
session = cluster.connect()

# 👉 เลือกใช้ Keyspace
session.set_keyspace('stock_data')

# 👉 ตรวจสอบและสร้างตาราง (ถ้ายังไม่มี)
session.execute("""
    CREATE TABLE IF NOT EXISTS candlestick_data (
        symbol TEXT,
        time TIMESTAMP PRIMARY KEY,
        open_price FLOAT,
        high_price FLOAT,
        low_price FLOAT,
        close_price FLOAT,
        volume INT,
        value FLOAT
    )
""")
print("✅ Keyspace และ Table พร้อมใช้งาน!")

# 👉 ฟังก์ชันดึงข้อมูลหุ้น
def fetch_and_store_stock(symbol="BBL", interval="1d", limit=10):
    res = market.get_candlestick(symbol=symbol, interval=interval, limit=limit, normalized=True)

    if not res:
        print(f"⚠️ ไม่พบข้อมูลสำหรับ {symbol}")
        return

    for i in range(len(res["time"])):
        timestamp = datetime.fromtimestamp(res["time"][i])  
        open_price = res["open"][i]
        high_price = res["high"][i]
        low_price = res["low"][i]
        close_price = res["close"][i]
        volume = res["volume"][i]
        value = res["value"][i]

        session.execute("""
            INSERT INTO candlestick_data (symbol, time, open_price, high_price, low_price, close_price, volume, value)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """, (symbol, timestamp, open_price, high_price, low_price, close_price, volume, value))

    print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

# 👉 ทดสอบดึงข้อมูลหุ้น BBL
fetch_and_store_stock(symbol="BBL", interval="1d", limit=10)
# Out:
# ✅ Keyspace และ Table พร้อมใช้งาน!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBL สำเร็จ!

# %%
from cassandra.cluster import Cluster

# 👉 เชื่อมต่อ Cassandra
cluster = Cluster(['127.0.0.1'])  # ถ้าเป็น localhost
session = cluster.connect()

# 👉 เลือก Keyspace
session.set_keyspace('stock_data')

# 👉 ดึงรายชื่อตารางทั้งหมดใน Keyspace
rows = session.execute("SELECT table_name FROM system_schema.tables WHERE keyspace_name = 'stock_data'")

print("📌 ตารางที่อยู่ใน Keyspace 'stock_data':")
for row in rows:
    print("-", row.table_name)

# 👉 เช็คโครงสร้างของตาราง candlestick_data
table_info = session.execute("SELECT * FROM system_schema.columns WHERE keyspace_name = 'stock_data' AND table_name = 'candlestick_data'")

print("\n📌 โครงสร้างของตาราง 'candlestick_data':")
for column in table_info:
    print("-", column.column_name, column.type)
# Out:
# 📌 ตารางที่อยู่ใน Keyspace 'stock_data':
# - candlestick_data
#
# 📌 โครงสร้างของตาราง 'candlestick_data':
# - close_price float
# - high_price float
# - low_price float
# - open_price float
# - symbol text
# - time timestamp
# - value float
# - volume int

# %%
import pandas as pd
import time

# ✅ โหลดรายชื่อหุ้นทั้งหมดจากไฟล์ CSV
try:
    symbols_df = pd.read_csv("/Users/fis008/Downloads/thai_stocks.csv")  # ไฟล์ต้องมีคอลัมน์ 'symbol'
    symbols = symbols_df['symbol'].dropna().tolist()
except FileNotFoundError:
    print("❌ ไม่พบไฟล์ 'thai_stocks.csv' ใช้รายชื่อหุ้นที่กำหนดแทน")
    symbols = ["PTT", "AOT", "SCB", "CPALL", "ADVANC"]

# ✅ ฟังก์ชันที่ดึงข้อมูล Financial Data สำหรับหุ้นแต่ละตัว
def insert_financial_data(symbol):
    try:
        # 👉 ดึงข้อมูลจาก Settrade API หรือแหล่งข้อมูลอื่น ๆ
        res = market.get_candlestick(symbol=symbol, interval="1d", limit=10, normalized=True)

        if not res:
            print(f"⚠️ ไม่พบข้อมูลสำหรับ {symbol}")
            return

        # 👉 เชื่อมต่อ Cassandra (หรือฐานข้อมูลอื่น ๆ)
        from cassandra.cluster import Cluster
        cluster = Cluster(['127.0.0.1'])  # ถ้าเป็น localhost
        session = cluster.connect()
        session.set_keyspace('stock_data')

        # 👉 วนลูปเก็บข้อมูล
        for i in range(len(res["time"])):
            timestamp = datetime.fromtimestamp(res["time"][i])  
            open_price = res["open"][i]
            high_price = res["high"][i]
            low_price = res["low"][i]
            close_price = res["close"][i]
            volume = res["volume"][i]
            value = res["value"][i]

            # 👉 แทรกข้อมูลลงในตาราง
            session.execute("""
                INSERT INTO candlestick_data (symbol, time, open_price, high_price, low_price, close_price, volume, value)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            """, (symbol, timestamp, open_price, high_price, low_price, close_price, volume, value))

        print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น {symbol}: {e}")

# ✅ ดึงข้อมูล Financial Data สำหรับหุ้นทุกตัว
for symbol in symbols:
    insert_financial_data(symbol)
    time.sleep(2)  # ⏳ ควบคุม API Rate Limit
# Out:
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 24CS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 2S สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 3BBIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น A สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น A5 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AAI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AAV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ABM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADVANC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADVICE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AEONTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AGE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AHC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIMCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIMIRT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIRA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AJ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AJA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALLA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALLY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALPHAX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALUCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMANAH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMARC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMARIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATAV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ANAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ANI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AOT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APCS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APURE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AQUA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARIP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARROW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASEFA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIMAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ATP30 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AU สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AUCT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AURA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AWC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AXTRART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AYUD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B52 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAFS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BANPU สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBIK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCPG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BDMS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BE8 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEAUTY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEYOND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGRIM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIOTEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIZ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BJC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BJCHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKIH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLESS สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น BLISS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BOFFICE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BOL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BPP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BPS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BROCK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRRGIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSBM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTNC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTSGIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BUI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BVG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BWG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B-WORK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BYD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CAZ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CBG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CCET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CENTEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CEYE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CFARM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CFRESH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CGD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CGH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHAO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHARAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHASE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHAYO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHEWA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHIC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHOTI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHOW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIMBT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CITY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIVIL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CKP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CNT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COCOCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COLOR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COM7 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPALL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPANEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPAXT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPNCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPNREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPTREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRANE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CREDIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CTARAF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CWT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น D สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DDD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DELTA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DEMCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DEXON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DHOUSE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DIMET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DITTO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DMT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DOD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DOHOME สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DPAINT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DRT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DTCENT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DTCI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DUSIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DV8 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EASON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EASTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ECF สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น ECL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EFORL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EGATIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EGCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EKH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EPG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ERW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ESTAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EURO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EVER สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น F&D สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FANCY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FLOYD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FMT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FNS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FORTH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FSMART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FSX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FUTURERT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FVC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GABLE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GAHREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GBX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GCAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GENCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GFPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GJS สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLOBAL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLOCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLORY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GPSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GRAMMY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GRAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GREEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GROREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GSTEEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GTB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GTV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GULF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GUNKUL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GVREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GYT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HANA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HARN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HEALTH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HENG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HFT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HMPRO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HTECH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HUMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HYDRO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HYDROGEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น I2 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IFS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IHL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น III สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ILINK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ILM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IMH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IMPACT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INETREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INGRS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INOX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INSET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INSURE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INTUCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IROYAL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRPC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ISSARA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITNS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITTHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IVF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IVL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น J สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JAK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JAS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JCK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JCKH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JCT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JDF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JKN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JMART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JMT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JPARK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JSP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JUBILE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น K สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KAMART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KASET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KBANK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KBS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KBSPIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KCAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KCE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KCM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KDH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KEX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KGEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KIAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KISS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KJL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KKC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KKP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KLINIQ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KOOL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KPNREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KSL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KTB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KTBSTMR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KTIS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KTMS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KUMWEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KUN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KWC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KWI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KWM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น KYE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น L&E สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LALIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LANNA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LDC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LEE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LEO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LHFG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LHHOTEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LHK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LHRREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LHSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LOXLEY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LPH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LPN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LRH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LST สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น LUXF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น M สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MAGURO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MAJOR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MALEE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MANRIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MASTER สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MATCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MATI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MBAX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MBK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MCA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น M-CHAI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MCOT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MCS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MDX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MEB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MEDEZE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MEGA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MENA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น META สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น METCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MFEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MGT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MICRO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MIDA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MII สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MILL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MINT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MIPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MITSIB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MJD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MJLF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ML สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MNIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MNIT2 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MNRF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MODERN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MONO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MOONG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MORE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MOSHI สำเร็จ!
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น MOTHER: Symbol not found [MOTHER]
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น M-PAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MPJ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MST สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น M-STOR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MTI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MUD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น MVP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NATION สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NCAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NCL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NDR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NEO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NEP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NER สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NETBAY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NEW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NEWS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NEX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NKI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NKT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NNCL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NOBLE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NOVA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NPK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NRF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NSL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NTSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NTV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NVD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NWR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น NYT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OHTL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OKJ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ONEE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ORI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ORN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น OSP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PACO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PAF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PANEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PATO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PCE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PCSGH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PDG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PDJ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PEACE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PEER สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PERM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PHG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PHOL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PICO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PIMO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PIS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PJW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLANB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLANET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PLUS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PMTA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น POLY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น POPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PORT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PPM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PPP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PPPM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PPS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PQS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PR9 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRAKIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRAPAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PREB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRECHA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRIME สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRINC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PROEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PROS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PROSPECT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PROUD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PRTR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PSG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PSH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PSL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PSP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PSTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTECH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTTEP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PTTGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น PYLON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น Q-CON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QHBREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QHHRREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QHOP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QLT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น QTCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RABBIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RATCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RBF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RCL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น READY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RICHY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RJH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RML สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ROCK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ROCTEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ROH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ROJNA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RPC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RPH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RSP สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น RSXYZ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น RWI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น S สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น S&J สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น S11 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SABINA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SABUY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAF สำเร็จ!
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SAFARI: Symbol not found [SAFARI]
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAFE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SALEE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAMART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAMCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAMTEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SANKO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAPPE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAUCE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAWAD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SAWANG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCGD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCGP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SDC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SEAFCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SEAOIL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SECURE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SE-ED สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SEI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SELIC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SENA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SENX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SFLEX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SFT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SGF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SGP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SHANG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SHR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SIAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SICT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SIMAT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น SINGER สำเร็จ!
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SINO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SIRI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SIRIPRT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SIS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SISB: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SITHAI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SJWD: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SK: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SKE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SKN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SKR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SKY: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SLP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SMART: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SMD100: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SMIT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SMPC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SMT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SNC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SNNP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SNP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SNPS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SOLAR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SONIC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SORKON: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPACK: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPALI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPCG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPRC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPREME: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPRIME: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SPVI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SQ: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SRICHA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SRIPANWA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SRS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SSF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SSP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SSPF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SSSC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SST: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SSTRT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STANLY: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STECH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STECON: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STELLA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STGT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STOWER: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STPI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น STX: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUPER: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUPEREIF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUSCO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SUTHA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SVI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SVOA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SVR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SVT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SWC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SYMC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SYNEX: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น SYNTEC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TACC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TAE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TAKUNI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TAN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TAPAC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TASCO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TATG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TBN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TCAP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TCC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TCJ: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TCMC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TCOAT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TEAM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TEAMG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TEGH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TEKA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TERA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFFIF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFMAMA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGPRO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THAI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THANA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THANI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THCOM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THIP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THMUI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THRE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THREL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIDLOR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIF1: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIGER: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIPCO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIPH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TISCO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TITLE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TK: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TLHPF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TLI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMAN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMD: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMILL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMW: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNDT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNITY: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNPC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNPF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOPP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPAC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPBI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPCH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPCS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPIPL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPIPP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPLAS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPOLY: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPRIME: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TQM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TQR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRITN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRU: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRUBB: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRUE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRV: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSTE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSTH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTB: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTCL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTLPF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTW: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TU: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TU-PF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TURTLE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVDH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWPC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWZ: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TYCN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UAC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBIS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UEC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UKEM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UMI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UMS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UNIQ: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UOBKH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UPF: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UPOIC: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UREKA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UTP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UV: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UVAN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VARO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VCOM: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VGI: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VIBHA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VIH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VNG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VPO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VRANDA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VS: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WACOAL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WARRIX: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WAVE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WELL: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WFX: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WGE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHABT: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHAIR: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHART: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHAUP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WICE: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WIIK: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WIN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINDOW: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINMED: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINNER: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WORK: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WP: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WPH: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XBIO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XO: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XPG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YGG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YONG: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YUASA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZAA: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZEN: can't start new thread
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZIGA: can't start new thread

# %%
from cassandra.cluster import Cluster
import pandas as pd

# เชื่อมต่อกับ Cassandra
cluster = Cluster(['127.0.0.1'])  # ระบุ IP ของ Cassandra node ที่คุณใช้งาน
session = cluster.connect('stock_data')  # เปลี่ยนเป็น keyspace ของคุณ

# สั่งเลือกข้อมูลจากตาราง candlestick_data
symbol = "SAM"
query = f"SELECT time, open_price, high_price, low_price, close_price FROM candlestick_data WHERE symbol = '{symbol}' ALLOW FILTERING;"

# ดึงข้อมูลจาก Cassandra
rows = session.execute(query)

# สร้าง DataFrame จากผลลัพธ์
data = []
for row in rows:
    data.append({
        "time": row.time,
        "open_price": row.open_price,
        "high_price": row.high_price,
        "low_price": row.low_price,
        "close_price": row.close_price
    })

df = pd.DataFrame(data)

# แสดง DataFrame
print(df)
# Out:
#         time  open_price  high_price  low_price  close_price
# 0 2025-02-20        0.17        0.18       0.16         0.18
# 1 2025-02-14        0.16        0.16       0.15         0.16
# 2 2025-02-19        0.16        0.18       0.16         0.17
# 3 2025-02-17        0.15        0.16       0.15         0.16
# 4 2025-02-18        0.15        0.17       0.15         0.16

# %%
from cassandra.cluster import Cluster
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


# Plotting the stock data using Matplotlib
plt.figure(figsize=(10, 6))

# Plot Close Price
plt.plot(df['time'], df['close_price'], label="Close Price", color='blue', marker='o')

# Plot Open Price
plt.plot(df['time'], df['open_price'], label="Open Price", color='green', marker='x')

# Plot High Price
plt.plot(df['time'], df['high_price'], label="High Price", color='red', marker='^')

# Plot Low Price
plt.plot(df['time'], df['low_price'], label="Low Price", color='orange', marker='v')

# Adding labels and title
plt.title('Stock Price Movement for BBL', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (THB)', fontsize=12)
plt.legend(loc='best')

# Formatting the x-axis to show dates properly
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
